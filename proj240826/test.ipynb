# %%
from bank_client import *
from proj240826.bank_client import BankClient

# %%
cd = ClientData()

# %%
d = cd.data()
dl = d[d["cuid"]==15].to_dict()
cl = BankClient(**{l: str(dl[l][0]) for l in dl})

# %%
print(cl)
# Out:
# Robin Palan (15)

# %%
list(d.columns)
# Out:
# ['cuid', 'name', 'surname']

# %%
15 in list(d["cuid"])
# Out:
# True

# %%
ddd = {"cuid": 9, "name": "A", "surname": "B"}
d._concat(ddd, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_19846/137456217.py in ?()
#       1 ddd = {"cuid": 9, "name": "A", "surname": "B"}
# ----> 2 d._concat(ddd, ignore_index=True)
#
# ~/anaconda3/envs/ohen/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute '_concat'

# %%
cd.add_client()
# Out:
# 9256

# %%
print(cd.get_client(9256))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(cd.get_client(9256))
#
# File ~/python/ohen/proj240826/bank_client.py:27, in ClientData.get_client(self, client_id)
#      25 def get_client(self, client_id: int) -> BankClient:
#      26     dl = self.__data[self.__data["cuid"]==client_id].to_dict()
# ---> 27     return BankClient(**{l: str(dl[l][dl[l].keys[0]]) for l in dl})
#
# File ~/python/ohen/proj240826/bank_client.py:27, in <dictcomp>(.0)
#      25 def get_client(self, client_id: int) -> BankClient:
#      26     dl = self.__data[self.__data["cuid"]==client_id].to_dict()
# ---> 27     return BankClient(**{l: str(dl[l][dl[l].keys[0]]) for l in dl})
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
# Out:
# {'cuid': {2: 1062}, 'name': {2: 'Jiří VIII'}, 'surname': {2: 'Tudor'}}
